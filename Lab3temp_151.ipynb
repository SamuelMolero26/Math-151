# %% [markdown]
# ## MATH 151 Lab  3

# %% [markdown]
# Samuel Molero, Dylan Yi, and William Meerbott.

# %%
from sympy import *
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
#start code here
x = Symbol('x')
g = (x ** 4)*sin(pi/(x**3))-4
display(g)
limit1 = limit(g,x,0)
print('The limit as x -- > 0 is :' ,limit1)
# Out:
# x**4*sin(pi/x**3) - 4
# The limit as x -- > 0 is : -4

# %% [markdown]
# #### 1b

# %%
#start code here
f = (x ** 4) -4
h = -(x**4) -  4

plot((f,(x,-0.75,0.75)),(h,(x,-0.75,0.75)))

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
#start code here
x=symbols('x')
f1=100*E**(-x/100)-0.01*(x**2)
plot(f1)
print(solve(f1,x))
# Out:
# [70.3467422498392, -158.804726468938 + 154.022350102076*I]

# %% [markdown]
# #### 2b

# %%
#start code here
f2=atan(x)+x-1
plot(f2)
lim2=nsolve(f2,x,0)
print(lim2)
# Out:
# 0.520268992719590

# %% [markdown]
# #### 2c

# %%
#start code here
f3=ln(x)-x+sqrt(100-(x**2))
plot(f3)
lim3=nsolve(f3,x,8)
print(lim3)
# Out:
# 8.03583332147666

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
#start code here
x = Symbol('x')
f = sqrt((3*x**2)+3) / (1 - 3*x)
display(f)
plot(f,(x,-5,5))
print("Only has 1 verticla dn 1 horizontal asymptote")
# Out:
# sqrt(3*x**2 + 3)/(1 - 3*x)
# Only has 1 verticla dn 1 horizontal asymptote

# %% [markdown]
# #### 3b

# %%
#start code here
x = Symbol('x')
f = sqrt((3*x**2)+3) / (1 - (3*x))
list1 = [10.0,50.0,100.0]
list2 = [-10.0,-50.0,-100.0]
f.evalf()
for i in list1:
    print(i,':',f.subs(x,i))
print()
for i in list2:
    print(i,':',f.subs(x,i))
# Out:
# 10.0 : -0.600237765018249
# 50.0 : -0.581341336609497
# 100.0 : -0.579310169881037
#
# -10.0 : 0.561512747920297
# -50.0 : 0.573641451356391
# -100.0 : 0.575460932871861

# %% [markdown]
# #### 3c

# %%
print("As x aproaches + infinity")
limit1 = limit(f,x,oo,'+')
print(limit1.evalf())

print("As x aproaches - infinity")
limt2 = limit(f,x,oo,'-')
print(limt2.evalf())
# Out:
# As x aproaches + infinity
# -0.577350269189626
# As x aproaches - infinity
# -0.577350269189626

# %% [markdown]
# #### 3d

# %%
print("Both part prove the continuity of an infiity limit, as seen onf the graph on part a and by part b, the graph never touches the x axis and x is constantly increasing.")
# Out:
# Both part prove the continuity of an infiity limit, as seen onf the graph on part a and by part b, the graph never touches the x axis and x is constantly increasing.

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### 4a

# %%
x =symbols('x',positive=True)
vt= 1*(1-E**((-9*x)/1))
lim=limit(vt,x,oo)
print(lim)
print('So as t goes to infinity o the limit gets closer to one. This makes sense due to e getting a higher and higher negative power which makes the limit get closer to one as e is subtracting from 1.')
# Out:
# 1
# So as t goes to infinity o the limit gets closer to one. This makes sense due to e getting a higher and higher negative power which makes the limit get closer to one as e is subtracting from 1.

# %% [markdown]
# #### 4b

# %%
t = symbols('t')
vt=1*(1-exp((-1*9.8*t)/1))
plot(vt,(t,0,1))
print('The soultion reaches 99% of its terminal velocity at .47 seconds.')
# Out:
# The soultion reaches 99% of its terminal velocity at .47 seconds.
